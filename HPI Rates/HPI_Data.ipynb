# %%
import pandas as pd

# %%
csv_path = "HPI_master.csv"
hpi_data = pd.read_csv(csv_path)
hpi_data.head(10)
# Out:
#       hpi_type     hpi_flavor frequency                   level  \
# 0  traditional  purchase-only   monthly  USA or Census Division
# 1  traditional  purchase-only   monthly  USA or Census Division
# 2  traditional  purchase-only   monthly  USA or Census Division
# 3  traditional  purchase-only   monthly  USA or Census Division
# 4  traditional  purchase-only   monthly  USA or Census Division
# 5  traditional  purchase-only   monthly  USA or Census Division
# 6  traditional  purchase-only   monthly  USA or Census Division
# 7  traditional  purchase-only   monthly  USA or Census Division
# 8  traditional  purchase-only   monthly  USA or Census Division
# 9  traditional  purchase-only   monthly  USA or Census Division
#
#                     place_name place_id    yr  period  index_nsa  index_sa
# 0  East North Central Division   DV_ENC  1991       1     100.00    100.00
# 1  East North Central Division   DV_ENC  1991       2     100.99    101.07
# ...

# %%
clean_hpi = hpi_data[["place_name", "yr", "period", "index_nsa", "index_sa"]]
clean_hpi.head(10)
# Out:
#                     place_name    yr  period  index_nsa  index_sa
# 0  East North Central Division  1991       1     100.00    100.00
# 1  East North Central Division  1991       2     100.99    101.07
# 2  East North Central Division  1991       3     101.36    101.00
# 3  East North Central Division  1991       4     101.75    101.05
# 4  East North Central Division  1991       5     102.39    101.44
# 5  East North Central Division  1991       6     102.82    101.56
# 6  East North Central Division  1991       7     103.02    101.94
# 7  East North Central Division  1991       8     103.18    102.12
# 8  East North Central Division  1991       9     102.87    102.05
# 9  East North Central Division  1991      10     103.09    102.40

# %%
renamed_hpi = clean_hpi.rename(columns={"place_name": "Place Name",
                                                "yr": "Year",
                                                "period": "Month",
                                                "index_nsa": "NSA Index",
                                                "index_sa": "SA Index"})
renamed_hpi.head(10)
# Out:
#                     Place Name  Year  Month  NSA Index  SA Index
# 0  East North Central Division  1991      1     100.00    100.00
# 1  East North Central Division  1991      2     100.99    101.07
# 2  East North Central Division  1991      3     101.36    101.00
# 3  East North Central Division  1991      4     101.75    101.05
# 4  East North Central Division  1991      5     102.39    101.44
# 5  East North Central Division  1991      6     102.82    101.56
# 6  East North Central Division  1991      7     103.02    101.94
# 7  East North Central Division  1991      8     103.18    102.12
# 8  East North Central Division  1991      9     102.87    102.05
# 9  East North Central Division  1991     10     103.09    102.40

# %%
renamed_hpi.head(10)
# Out:
#                     Place Name  Year  Month  NSA Index  SA Index
# 0  East North Central Division  1991      1     100.00    100.00
# 1  East North Central Division  1991      2     100.99    101.07
# 2  East North Central Division  1991      3     101.36    101.00
# 3  East North Central Division  1991      4     101.75    101.05
# 4  East North Central Division  1991      5     102.39    101.44
# 5  East North Central Division  1991      6     102.82    101.56
# 6  East North Central Division  1991      7     103.02    101.94
# 7  East North Central Division  1991      8     103.18    102.12
# 8  East North Central Division  1991      9     102.87    102.05
# 9  East North Central Division  1991     10     103.09    102.40

# %%
renamed_hpi.diff(axis = 0, periods = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-fc4cd65e687b> in <module>
# ----> 1 renamed_hpi.diff(axis = 0, periods = 1)
#
# //anaconda2/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in diff(self, periods, axis)
#    6592         """
#    6593         bm_axis = self._get_block_manager_axis(axis)
# -> 6594         new_data = self._data.diff(n=periods, axis=bm_axis)
#    6595         return self._constructor(new_data)
#    6596
#
# //anaconda2/envs/PythonData/lib/python3.7/site-packages/pandas/core/internals/managers.py in diff(self, **kwargs)
#     564
#     565     def diff(self, **kwargs):
# --> 566         return self.apply("diff", **kwargs)
#     567
#     568     def interpolate(self, **kwargs):
#
# ...
